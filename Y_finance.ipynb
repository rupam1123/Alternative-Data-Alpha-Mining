# %%
import yfinance as yf
import pandas as pd
from tqdm import tqdm
import os

# Load tickers from all sources (assuming you've combined them already)
reddit = pd.read_csv("/home/rupam/DataAlpha/data/raw/processed/reddit_sentiment_2020.csv")
google = pd.read_csv("/home/rupam/DataAlpha/data/raw/processed/google_trends_sentiment_2020.csv")
news = pd.read_csv("/home/rupam/DataAlpha/data/raw/processed/news_sentiment_2020.csv")

# Combine tickers
all_tickers = set(reddit["ticker"]).union(set(google["ticker"])).union(set(news["ticker"]))
print(f"✅ Total unique tickers to fetch: {len(all_tickers)}")

# Set output path
os.makedirs("/home/rupam/DataAlpha/data/raw/Stock_prices", exist_ok=True)

# Fetch and save each ticker's OHLC data
failed = []
for ticker in tqdm(all_tickers, desc="📉 Fetching OHLC data"):
    try:
        df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
        if df.empty:
            failed.append(ticker)
            continue
        df.reset_index(inplace=True)
        df["ticker"] = ticker
        df.to_csv(f"/home/rupam/DataAlpha/data/raw/Stock_prices/{ticker}.csv", index=False)
    except Exception as e:
        print(f"❌ Error fetching {ticker}: {e}")
        failed.append(ticker)

print(f"✅ Completed. Failed tickers: {len(failed)}")
# Out:
# ✅ Total unique tickers to fetch: 493
# 📉 Fetching OHLC data:   0%|          | 0/493 [00:00<?, ?it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   0%|          | 1/493 [00:01<14:54,  1.82s/it]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   0%|          | 2/493 [00:03<12:21,  1.51s/it]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   1%|          | 3/493 [00:03<08:40,  1.06s/it]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   1%|          | 4/493 [00:04<06:28,  1.26it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   1%|          | 5/493 [00:04<06:21,  1.28it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   1%|          | 6/493 [00:05<05:47,  1.40it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   1%|▏         | 7/493 [00:06<07:58,  1.02it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   2%|▏         | 8/493 [00:07<06:56,  1.16it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   2%|▏         | 9/493 [00:07<05:40,  1.42it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   2%|▏         | 10/493 [00:08<04:51,  1.66it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   2%|▏         | 11/493 [00:08<04:35,  1.75it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   2%|▏         | 12/493 [00:09<04:41,  1.71it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   3%|▎         | 13/493 [00:09<04:11,  1.91it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   3%|▎         | 14/493 [00:10<04:13,  1.89it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   3%|▎         | 15/493 [00:10<04:25,  1.80it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   3%|▎         | 16/493 [00:11<04:20,  1.83it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   3%|▎         | 17/493 [00:12<04:25,  1.79it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   4%|▎         | 18/493 [00:12<04:00,  1.98it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   4%|▍         | 19/493 [00:12<03:58,  1.99it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   4%|▍         | 20/493 [00:13<03:52,  2.03it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   4%|▍         | 21/493 [00:13<03:47,  2.07it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   4%|▍         | 22/493 [00:14<03:31,  2.23it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   5%|▍         | 23/493 [00:14<03:18,  2.36it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   5%|▍         | 24/493 [00:14<03:09,  2.47it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   5%|▌         | 25/493 [00:15<03:21,  2.32it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   5%|▌         | 26/493 [00:15<03:12,  2.43it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   5%|▌         | 27/493 [00:16<03:38,  2.13it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   6%|▌         | 28/493 [00:16<03:50,  2.02it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   6%|▌         | 29/493 [00:17<03:52,  2.00it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   6%|▌         | 30/493 [00:17<03:40,  2.10it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   6%|▋         | 31/493 [00:18<03:28,  2.22it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   6%|▋         | 32/493 [00:18<03:53,  1.97it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   7%|▋         | 33/493 [00:19<03:41,  2.08it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   7%|▋         | 34/493 [00:19<03:39,  2.10it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   7%|▋         | 35/493 [00:20<03:31,  2.17it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   7%|▋         | 36/493 [00:20<03:39,  2.08it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   8%|▊         | 37/493 [00:21<03:46,  2.01it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   8%|▊         | 38/493 [00:21<03:33,  2.13it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   8%|▊         | 39/493 [00:22<03:38,  2.07it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   8%|▊         | 40/493 [00:22<03:56,  1.91it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   8%|▊         | 41/493 [00:23<03:34,  2.11it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   9%|▊         | 42/493 [00:23<03:27,  2.18it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   9%|▊         | 43/493 [00:24<03:36,  2.08it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   9%|▉         | 44/493 [00:24<03:53,  1.92it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   9%|▉         | 45/493 [00:25<04:05,  1.82it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:   9%|▉         | 46/493 [00:25<03:48,  1.95it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  10%|▉         | 47/493 [00:26<04:01,  1.85it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  10%|▉         | 48/493 [00:26<03:43,  1.99it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SW']: YFPricesMissingError('possibly delisted; no price data found  (1d 2020-01-01 -> 2020-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1577854800, endDate = 1609390800")')
# 📉 Fetching OHLC data:  10%|▉         | 49/493 [00:27<03:50,  1.93it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  10%|█         | 50/493 [00:27<04:06,  1.80it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  10%|█         | 51/493 [00:28<04:00,  1.84it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  11%|█         | 52/493 [00:29<04:09,  1.76it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  11%|█         | 53/493 [00:29<03:51,  1.90it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  11%|█         | 54/493 [00:29<03:35,  2.04it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  11%|█         | 55/493 [00:30<03:41,  1.98it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  11%|█▏        | 56/493 [00:30<03:29,  2.08it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  12%|█▏        | 57/493 [00:31<03:21,  2.16it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  12%|█▏        | 58/493 [00:31<03:44,  1.94it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  12%|█▏        | 59/493 [00:32<03:43,  1.94it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['COIN']: YFPricesMissingError('possibly delisted; no price data found  (1d 2020-01-01 -> 2020-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1577854800, endDate = 1609390800")')
# 📉 Fetching OHLC data:  12%|█▏        | 60/493 [00:33<04:18,  1.68it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  12%|█▏        | 61/493 [00:33<04:12,  1.71it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  13%|█▎        | 62/493 [00:34<03:59,  1.80it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  13%|█▎        | 63/493 [00:34<04:02,  1.77it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  13%|█▎        | 64/493 [00:35<04:02,  1.77it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  13%|█▎        | 65/493 [00:36<03:58,  1.80it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  13%|█▎        | 66/493 [00:36<03:37,  1.96it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  14%|█▎        | 67/493 [00:37<03:48,  1.86it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  14%|█▍        | 68/493 [00:37<03:32,  2.00it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  14%|█▍        | 69/493 [00:37<03:23,  2.08it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  14%|█▍        | 70/493 [00:38<03:35,  1.97it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  14%|█▍        | 71/493 [00:39<03:47,  1.86it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  15%|█▍        | 72/493 [00:39<03:46,  1.86it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  15%|█▍        | 73/493 [00:39<03:28,  2.02it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  15%|█▌        | 74/493 [00:40<03:21,  2.08it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  15%|█▌        | 75/493 [00:40<03:18,  2.11it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  15%|█▌        | 76/493 [00:41<03:05,  2.25it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  16%|█▌        | 77/493 [00:41<03:08,  2.20it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  16%|█▌        | 78/493 [00:42<03:12,  2.16it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  16%|█▌        | 79/493 [00:42<03:18,  2.09it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:
/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  97%|█████████▋| 480/493 [04:16<00:13,  1.01s/it]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  98%|█████████▊| 481/493 [04:17<00:12,  1.00s/it]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  98%|█████████▊| 482/493 [04:18<00:10,  1.01it/s]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  98%|█████████▊| 483/493 [04:19<00:10,  1.06s/it]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  98%|█████████▊| 484/493 [04:20<00:09,  1.03s/it]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  98%|█████████▊| 485/493 [04:21<00:08,  1.02s/it]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  99%|█████████▊| 486/493 [04:22<00:07,  1.04s/it]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  99%|█████████▉| 487/493 [04:23<00:06,  1.01s/it]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  99%|█████████▉| 488/493 [04:26<00:07,  1.57s/it]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  99%|█████████▉| 489/493 [04:27<00:05,  1.39s/it]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data:  99%|█████████▉| 490/493 [04:28<00:03,  1.30s/it]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data: 100%|█████████▉| 491/493 [04:29<00:02,  1.25s/it]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data: 100%|█████████▉| 492/493 [04:30<00:01,  1.21s/it]/tmp/ipykernel_226624/1795103521.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# 📉 Fetching OHLC data: 100%|██████████| 493/493 [04:31<00:00,  1.81it/s]
# ✅ Completed. Failed tickers: 5

# %%
failed
# Out:
# ['SW', 'COIN', 'GEHC', 'KVUE', 'EXE']

# %%
import os
import pandas as pd
from tqdm import tqdm

# Input/output folders
price_folder = "/home/rupam/DataAlpha/data/raw/Stock_prices"
output_folder = "/home/rupam/DataAlpha/data/raw/returns"
os.makedirs(output_folder, exist_ok=True)

# List all CSV files
csv_files = [f for f in os.listdir(price_folder) if f.endswith(".csv")]
print(f"📁 Found {len(csv_files)} stock files")

failed = []

for file in tqdm(csv_files, desc="📊 Calculating returns"):
    try:
        file_path = os.path.join(price_folder, file)

        # ✅ Read with correct headers (row 0) and skip row 1 (ticker names)
        df = pd.read_csv(file_path, skiprows=[1])

        # Ensure required columns exist
        if "Date" not in df.columns or "Close" not in df.columns:
            raise ValueError("Missing required columns")

        # Convert and sort dates
        df["Date"] = pd.to_datetime(df["Date"], errors="coerce")
        df = df.dropna(subset=["Date"])
        df = df.sort_values("Date")

        # Calculate daily return
        df["return"] = df["Close"].pct_change()

        # Add ticker from filename
        df["ticker"] = file.replace(".csv", "")

        # Drop NaN returns
        df = df.dropna(subset=["return"])

        # Keep only required columns
        df = df[["Date", "ticker", "return"]]
        df.rename(columns={"Date": "date"}, inplace=True)

        # Save to output
        df.to_csv(os.path.join(output_folder, file), index=False)

    except Exception as e:
        print(f"❌ Failed: {file} -> {e}")
        failed.append(file)

print(f"✅ Returns calculated for {len(csv_files) - len(failed)} tickers")
# Out:
# 📁 Found 488 stock files
# 📊 Calculating returns: 100%|██████████| 488/488 [00:03<00:00, 132.60it/s]
# ✅ Returns calculated for 488 tickers

# %%
import os
import pandas as pd
from tqdm import tqdm

# Paths
returns_folder = "/home/rupam/DataAlpha/data/raw/returns"
output_path = "/home/rupam/DataAlpha/data/raw/processed/all_returns.csv"

# List all return CSVs
return_files = [f for f in os.listdir(returns_folder) if f.endswith(".csv")]

# Collect DataFrames
all_returns = []

for file in tqdm(return_files, desc="📦 Merging return files"):
    try:
        df = pd.read_csv(os.path.join(returns_folder, file), parse_dates=["date"])
        all_returns.append(df)
    except Exception as e:
        print(f"❌ Failed: {file} -> {e}")

# Combine all returns
df_returns = pd.concat(all_returns, ignore_index=True)

# Save combined returns
df_returns.to_csv(output_path, index=False)
print(f"✅ Merged returns saved to: {output_path}")
# Out:
# 📦 Merging return files: 100%|██████████| 488/488 [00:01<00:00, 486.86it/s]
# ✅ Merged returns saved to: /home/rupam/DataAlpha/data/raw/processed/all_returns.csv

# %%
import pandas as pd
import os

# Load all pre-processed CSVs
returns_path = "/home/rupam/DataAlpha/data/raw/returns"
reddit_path = "/home/rupam/DataAlpha/data/raw/processed/reddit_sentiment_2020.csv"
news_path = "/home/rupam/DataAlpha/data/raw/processed/news_sentiment_2020.csv"
google_path = "/home/rupam/DataAlpha/data/raw/processed/google_trends_sentiment_2020.csv"

# Load returns (all files and concatenate)
all_returns = []
for file in os.listdir(returns_path):
    if file.endswith(".csv"):
        df = pd.read_csv(os.path.join(returns_path, file))
        all_returns.append(df)
returns = pd.concat(all_returns, ignore_index=True)

# Load sentiment/trend data
reddit = pd.read_csv(reddit_path)
news = pd.read_csv(news_path)
google = pd.read_csv(google_path)

# --------------------------
# 1. Clean and standardize
# --------------------------
for df in [returns, reddit, news, google]:
    df["ticker"] = df["ticker"].astype(str).str.strip().str.upper()
    df["date"] = pd.to_datetime(df["date"]).dt.date

# Rename score columns to avoid collision
reddit = reddit.rename(columns={"sentiment": "reddit_sentiment"})
news = news.rename(columns={"sentiment": "news_sentiment"})
google = google.rename(columns={"trend_score": "google_trend"})

# --------------------------
# 2. Merge all data
# --------------------------
df = returns.copy()
df = df.merge(reddit, on=["date", "ticker"], how="left")
df = df.merge(news, on=["date", "ticker"], how="left")
df = df.merge(google, on=["date", "ticker"], how="left")

# --------------------------
# 3. Optional Forward Fill (limit to 2 days)
# --------------------------
df = df.sort_values(["ticker", "date"])
df["reddit_sentiment"] = df.groupby("ticker")["reddit_sentiment"].ffill(limit=2)
df["news_sentiment"] = df.groupby("ticker")["news_sentiment"].ffill(limit=2)
df["google_trend"] = df.groupby("ticker")["google_trend"].ffill(limit=2)

# --------------------------
# 4. Save final dataset
# --------------------------
output_path = "/home/rupam/DataAlpha/data/raw/processed/final_features.csv"
df.to_csv(output_path, index=False)
print(f"✅ Final dataset saved to {output_path}")

# --------------------------
# 5. Inspect missing data stats
# --------------------------
missing = df[["reddit_sentiment", "news_sentiment", "google_trend"]].isna().mean()
print("🔍 Percentage of missing values:")
print(missing.round(3))
# Out:
# ✅ Final dataset saved to /home/rupam/DataAlpha/data/raw/processed/final_features.csv
# 🔍 Percentage of missing values:
# reddit_sentiment    0.855
# news_sentiment      0.996
# google_trend        1.000
# dtype: float64

# %%
print(google.head())
print(google.columns)
print(google["ticker"].unique()[:5])
# Out:
#          date  google_trend ticker
# 0  2019-12-29            29    MMM
# 1  2020-01-05            25    MMM
# 2  2020-01-12            25    MMM
# 3  2020-01-19            25    MMM
# 4  2020-01-26            63    MMM
# Index(['date', 'google_trend', 'ticker'], dtype='object')
# ['MMM' 'AOS' 'ABT' 'ABBV' 'ACN']
